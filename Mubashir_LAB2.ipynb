# %% [markdown]
# <a href="https://colab.research.google.com/github/Mubashir-teapot/Artifical-Intellgence/blob/main/Mubashir_LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
from google import genai

client = genai.Client(api_key="YOUR_GEMINI_API_KEY")

print("🤖 Gemini Chatbot")
print("Type 'bye', 'goodbye', 'exit', or 'quit' to stop.\n")

while True:

    user = input("You: ").strip()

    # Exit commands
    if user.lower() in ["bye", "goodbye", "exit", "quit"]:
        print("Bot: Goodbye! ")
        break

    # Greetings
    if user.lower() in ["hi", "hello", "hey"]:
        print("Bot: Hello! How can I help you?")
        continue

    # Send message to Gemini
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=user
    )

    print("Bot:", response.text)
# Out:
# 🤖 Gemini Chatbot
# Type 'bye', 'goodbye', 'exit', or 'quit' to stop.
